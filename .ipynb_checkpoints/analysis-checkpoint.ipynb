# %%
import pandas as pd 
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Dataset/Spotify_Youtube.csv')

# %%
df.sample(10)
# Out:
#        Unnamed: 0             Artist  \
# 6007         6007          J.J. Cale
# 4130         4130        Erykah Badu
# 15367       15367  Sabrina Carpenter
# 6547         6547          Stan Getz
# 1276         1276        Bryan Adams
# 17706       17706              Blxst
# 11192       11192             JJ Lin
# 669           669                 U2
# 14762       14762        Young Dolph
# 13167       13167       benny blanco
#
#                                              Url_spotify  \
# 6007   https://open.spotify.com/artist/06nsZ3qSOYZ2hP...
# 4130   https://open.spotify.com/artist/7IfculRW2WXyzN...
# 15367  https://open.spotify.com/artist/74KM79TiuVKeVC...
# 6547   https://open.spotify.com/artist/0FMucZsEnCxs5p...
# 1276   https://open.spotify.com/artist/3Z02hBLubJxuFJ...
# 17706  https://open.spotify.com/artist/4qXC0i02bSFstE...
# 11192  https://open.spotify.com/artist/7Dx7RhX0mFuXhC...
# 669    https://open.spotify.com/artist/51Blml2LZPmy7T...
# ...

# %%
df.groupby(by=df['Artist'])['Views'].sum().reset_index()
# Out:
#               Artist         Views
# 0               $NOT  1.107849e+08
# 1        $uicideboy$  3.341351e+08
# 2           (G)I-DLE  1.754954e+09
# 3             *NSYNC  1.027833e+09
# 4          070 Shake  9.609936e+07
# ...              ...           ...
# 2074       will.i.am  2.831320e+09
# 2075  Ángela Aguilar  1.385295e+09
# 2076            Ñejo  6.266808e+08
# 2077      Ñengo Flow  8.127263e+08
# 2078        Øneheart  3.462331e+07
#
# [2079 rows x 2 columns]
